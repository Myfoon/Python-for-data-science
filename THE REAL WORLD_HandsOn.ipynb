# %% [markdown]
# ##  WHAT CAR SHOULD I BUY IN 2024 BASED ON THIS ANALYSIS?
# ### Why? Use the information and data supplied to consolidate your answer.

# %% [markdown]
# If you want exclusivity, you can get a Tesla Roadster (there are only 49 of them in Washington state with a population of 7.8 million)
# ![image.png](attachment:0e9eecd5-caea-40f2-90de-7086715a6771.png)
#
#
# If you spend most of your time in cities like Tacoma or Olympia and are not that concerned about the environment, I would be more cautious about buying a BEV and favor PHEVs, since they may not have a sufficiently developed charging network given the small number of electric cars (compared to Seattle, for example).(To be correct here, it would be nice to have not only the sum of cars for each city in Top 10 Cities with Electric Cars in Washington, but also the number of cars divided by the number of residents).
#
#
# ![image.png](attachment:262356b7-018a-4c86-b5f9-cbee4de66b6e.png)
#
#  Well, for a Seattle resident, you can certainly recommend something from BEVs, because as we can see from the Electric Vehicle Trend over the years, these cars are the future. These cars on average have a higher cost than PHEVs, but they may have a lower tax (it would be interesting to add this information to understand the total cost of purchase and ownership).
#
#  ![image.png](attachment:7186ee2f-2abc-404f-8148-1aa9f0b55681.png)

# %% [markdown]
# ## WHAT COUNTRY SHOULD I MOVE IN 2024 BASED ON THIS ANALYSIS?
# ### Why? Use the information and data supplied to consolidate your answer.

# %% [markdown]
# In general, especially if you are moving for a long period of time, you can be recommended one of the countries in Europe, as they have the lowest pollution growth rate.
# ![image.png](attachment:a61ea3ab-11c7-49df-a31f-64d4d3a57982.png)

# %% [markdown]
# If for some reason you need to go to Africa specifically, please choose everything except Nigeria.
#
# ![image.png](attachment:eb414ccc-a6f1-4127-9487-4d947518c3ac.png)

# %% [markdown]
# Maybe it is better to choose a smaller country, as there seems to be some correlation between country area and pollution rank.
#
# ![image.png](attachment:5b8dea6c-66ab-4e56-b500-220484e5fff1.png)
